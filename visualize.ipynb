# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
epoch1_batches = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 
                  1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 
                  2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700]

epoch1_loss = [0.7951, 0.6947, 0.6529, 0.6444, 0.6454, 0.6424, 0.6636, 0.6613, 0.6432, 0.6396,
               0.6323, 0.6261, 0.6199, 0.6122, 0.6070, 0.6031, 0.5978, 0.5951, 0.5910, 0.5899,
               0.5913, 0.5901, 0.5883, 0.5917, 0.5881, 0.5901, 0.5887, 0.5877, 0.5878, 0.5891,
               0.5891, 0.5881, 0.5884, 0.5875, 0.5878, 0.5873, 0.5867]

epoch1_acc = [0.3220, 0.4011, 0.4486, 0.4404, 0.4447, 0.4926, 0.4734, 0.4463, 0.4816, 0.4949,
              0.5147, 0.5251, 0.5303, 0.5438, 0.5376, 0.5733, 0.5803, 0.5922, 0.5868, 0.5820,
              0.6073, 0.6121, 0.6063, 0.6124, 0.6093, 0.6258, 0.6306, 0.6301, 0.6224, 0.6323,
              0.6482, 0.6529, 0.6523, 0.6480, 0.6435, 0.6733, 0.6764]

epoch1_token_acc = [0.6929, 0.7157, 0.7578, 0.7758, 0.7674, 0.7379, 0.7044, 0.7301, 0.7438,
                    0.7425, 0.7400, 0.7402, 0.7432, 0.7419, 0.7492, 0.7271, 0.7273, 0.7197,
                    0.7301, 0.7377, 0.7135, 0.7111, 0.7204, 0.7061, 0.7165, 0.6991, 0.6977,
                    0.6972, 0.7047, 0.6936, 0.6809, 0.6758, 0.6757, 0.6830, 0.6855, 0.6570, 0.6541]

# Data - Epoch 2 (batch numbers adjusted by adding 3774)
epoch2_batches = [x + 3774 for x in [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 
                                    1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 
                                    2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 
                                    3300, 3400, 3500, 3600, 3700]]

epoch2_loss = [0.5865, 0.5772, 0.5774, 0.5778, 0.5784, 0.5799, 0.5797, 0.5814, 0.5783, 0.5815, 0.5829,
               0.5816, 0.5834, 0.5816, 0.5814, 0.5853, 0.5844, 0.5845, 0.5835, 0.5832, 0.5852, 0.5846,
               0.5851, 0.5854, 0.5849, 0.5857, 0.5859, 0.5851, 0.5850, 0.5863, 0.5856, 0.5854, 0.5852,
               0.5849, 0.5849, 0.5845, 0.5844]

epoch2_acc = [0.5193, 0.5175, 0.5168, 0.5158, 0.5178, 0.5388, 0.5461, 0.5378, 0.5396, 0.5442, 0.5580,
              0.5644, 0.5605, 0.5685, 0.5567, 0.5868, 0.5906, 0.5982, 0.5908, 0.5855, 0.6093, 0.6128,
              0.6086, 0.6110, 0.6105, 0.6287, 0.6330, 0.6310, 0.6239, 0.6352, 0.6520, 0.6563, 0.6556,
              0.6523, 0.6479, 0.6761, 0.6794]

epoch2_token_acc = [0.7992, 0.7937, 0.7946, 0.7950, 0.7944, 0.7783, 0.7728, 0.7763, 0.7799, 0.7728,
                    0.7613, 0.7583, 0.7584, 0.7555, 0.7641, 0.7367, 0.7351, 0.7276, 0.7355, 0.7430,
                    0.7204, 0.7178, 0.7217, 0.7172, 0.7194, 0.7028, 0.6990, 0.7002, 0.7072, 0.6951,
                    0.6827, 0.6766, 0.6775, 0.6830, 0.6865, 0.6590, 0.6549]

# %%
all_batches = epoch1_batches + epoch2_batches
all_loss = epoch1_loss + epoch2_loss
all_acc = epoch1_acc + epoch2_acc
all_token_acc = epoch1_token_acc + epoch2_token_acc

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot accuracy metrics on primary axis (left)
ax1.plot(all_batches, all_acc, 'b-', label='Accuracy')
ax1.plot(all_batches, all_token_acc, 'g-', label='Token Accuracy')
ax1.set_xlabel('Cumulative Batch Number', fontsize=15)
ax1.set_ylabel('Accuracy', color='b', fontsize=15)
ax1.tick_params(axis='y', labelcolor='b')
ax1.set_ylim(0, 1)
ax1.grid(True, linestyle='--', alpha=0.7)

# Create secondary axis for loss (right)
ax2 = ax1.twinx()
ax2.plot(all_batches, all_loss, 'r-', label='Loss')
ax2.set_ylabel('Loss', color='r', fontsize=15)
ax2.tick_params(axis='y', labelcolor='r')
ax2.set_ylim(0, max(all_loss)*1.1)  # Add 10% padding at top

# Add title and legend
plt.title('Training Metrics vs. Cumulative Batch Number', fontsize=20)
fig.legend(loc='upper right', bbox_to_anchor=(0.9, 0.9))

# Add vertical lines and labels for epoch boundaries
ax1.axvline(x=3774, color='k', linestyle='--', alpha=0.5)
ax1.text(3774/2, 0.05, 'Epoch 1', ha='center', va='center', backgroundcolor='w')
ax1.text(3774 + (7548-3774)/2, 0.05, 'Epoch 2', ha='center', va='center', backgroundcolor='w')
ax1.axvline(x=7548, color='k', linestyle='--', alpha=0.5)

# Add validation points (from the logs)
# val_batches = [3774, 7548]  # End of each epoch
# val_loss = [0.5995, 0.5944]
# val_acc = [1.1972, 1.1819]
# ax2.plot(val_batches, val_loss, 'ro', markersize=8, label='Validation Loss')
# ax1.plot(val_batches, val_acc, 'bo', markersize=8, label='Validation Accuracy')

# Adjust layout
plt.tight_layout()
plt.show()
